# %% [markdown]
# <mark>演習1</mark> 情報数理学部のHPから抜き出した文章のテキストファイル`math_info.txt`に対して形態要素解析を行い、名詞の出現頻度を棒グラフとして表しなさい。

# %% [markdown]
# <mark>演習2</mark> `math_info.txt`に対して形態要素解析を行い、名詞の出現頻度に応じたWordCloudを作成しなさい。

# %% [markdown]
# <mark>演習3</mark> `forest-post.csv`は各都道府県における、森林率(森林面積を各都道府県の面積で割ったもの)と人口1万人あたりの郵便局の数である。それぞれのデータを色分けして日本地図上に表示させなさい。また、この二つのデータにどのような関係があると考えられるか、分析と考察を行いなさい。

# %% [markdown]
# ヒント：`prefectures.geojson`を読み込んだgeopandasデータフレームに、森林率と郵便局数の列を追加して、そのデータフレームを使ってプロットやデータ分析を行なってみる。
#
# ```python
# import geopandas as gpd
# import pandas as pd
#
# gdf = gpd.read_file('prefectures.geojson')
# forest_post = pd.read_csv('forest-post.csv')
#
# gdf['forest'] = forest_post['forest']
# gdf['post'] = forest_post['post']
# ```
