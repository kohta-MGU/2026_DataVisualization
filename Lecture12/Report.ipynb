# %% [markdown]
# データ可視化演習 最終課題
# ===================

# %% [markdown]
# ### 学籍番号：
# ### 名前　　：

# %% [markdown]
# ## 課題内容
# - ネット等から入手できるデータを用いて、これまで学んだデータ可視化法を使って分析し、レポートの形でまとめる。(JupyterNotebookあるいはWord形式)
# - データは個人で収集したものでも良いが、個人情報の取り扱いや使用許諾(著作権)等には注意すること。
# - 分析に用いた手法やPythonのプログラムコードもすべて記載し、可視化した結果からどのようなことが読み取れるか、といった考察もきちんと記載すること。
# - 内容については、オリジナリティや工夫があり、これまでの学修結果を十分に応用・活用できているものを高得点とする。
# - ほぼ同一の内容のレポートがあった場合、オリジナリティが不足していると判断し、大幅な減点とする。(人のものを写して作成したものは、写した人も写させた人も等しく減点するということです。)
# - 提出期限は7月31日(金)の午後11時55分までです。

# %% [markdown]
# (ここにレポートを書く)

# %%
#
# 使ったPythonコードやデータを可視化した実行結果を表示させる。
#
