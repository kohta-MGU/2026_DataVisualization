# %% [markdown]
# <mark>練習1</mark> `scores.csv`はあるテストの得点(`score`)と性別(`gender`)を記録したものである。このCSVデータをpandasのデータフレームとして読み込み、男性(M)および女性(F)ごとにデータを抽出して、男女別の統計データの表示やヒストグラムの作成を行いなさい。

# %% [markdown]
# <mark>演習2</mark> `height-weight.csv`のデータからpandasデータフレームを作成し、身長と体重のそれぞれのデータに対するヒストグラムを作成しなさい。

# %% [markdown]
# <mark>演習3</mark> `tokyo-temp.csv`、`height-weight.csv`、`elev-temp.csv`のそれぞれのデータに対して、pandasを使って様々な統計データを表示させるプログラムを作成しなさい。

# %% [markdown]
# <mark>演習4</mark> `tokyo-temp.csv`と`elev-temp.csv`のそれぞれのデータに対して、pandasを使って相関係数(相関行列)を求めるプログラムを作成しなさい。

# %% [markdown]
# <mark>演習5</mark> `tokyo-temp.csv`、`height-weight.csv`、`elev-temp.csv`のそれぞれのデータに対して、numpyを用いて回帰分析(線形回帰)を行い、pandasによるプロットと合わせて表示させなさい。
