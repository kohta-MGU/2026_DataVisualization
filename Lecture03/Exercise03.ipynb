# %% [markdown]
# <mark>練習 1</mark> 以下のデータは2010年から2022年までの国内の【原子力、石炭、天然ガス、石油、水力、太陽光、風力、地熱、バイオマス】に関する電源構成(発電量)を表したものである。(単位:億kWh) このデータを横軸を年とした時系列で折れ線グラフで表しなさい。
# ```python
# genshiryoku = [2882, 1018, 159, 93, 0, 94, 181, 329, 649, 638, 388, 708, 561]
# sekitan = [3199, 3058, 3340, 3571, 3544, 3560, 3447, 3472, 3311, 3252, 3093, 3177, 3046]
# tennengas = [3339, 4113, 4320, 4435, 4552, 4257, 4350, 4211, 4013, 3799, 3888, 3530, 3384]
# sekiyu = [983, 1583, 1885, 1567, 1161, 1006, 998, 888, 725, 638, 633, 762, 839]
# suiryoku = [838, 849, 765, 794, 835, 871, 795, 838, 810, 796, 784, 785, 767]
# taiyoukou = [35, 48, 66, 129, 230, 348, 458, 551, 627, 694, 791, 861, 926]
# fuuryoku = [40, 47, 48, 52, 52, 56, 62, 65, 75, 76, 90, 94, 93]
# chinetsu = [26, 27, 26, 26, 26, 26, 25, 25, 25, 28, 30, 30, 30]
# biomass = [152, 159, 168, 178, 182, 185, 197, 219, 236, 261, 288, 332, 372]
# ```

# %% [markdown]
# <mark>練習 2</mark> 上で作成したグラフに対して、線の種類、マーカー、色を変えたものを表示させなさい。（使用するものは自由です。）

# %% [markdown]
# <mark>練習 3</mark> 2010年と2022年の電源構成の割合をそれぞれ円グラフで表示させなさい。

# %% [markdown]
# <mark>練習 4</mark> これらのグラフの表示から何が読み取れるか、考察しなさい。

# %% [markdown]
# <mark>発展</mark> 上で作成したグラフの大きさ、日本語表示、凡例の位置などを工夫し、より見やすいグラフとなるように表示させなさい。
