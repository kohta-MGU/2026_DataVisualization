# %% [markdown]
# Exercise02
# ==========

# %% [markdown]
# <mark>演習 1</mark> 次のデータは、ある生徒のある1週間における1日あたりの睡眠時間(分)である。このデータ平均値を求めよ。
# ```python
# sleep_data = [400, 410, 420, 390, 430, 450, 440]

# %% [markdown]
# <mark>演習 2</mark> 次のデータは、8人の生徒の右手の握力を図った結果である。その中央値を求めよ。
# ```python
# grip = [38, 56, 43, 41, 35, 49, 51, 31]
# ```

# %% [markdown]
# <mark>演習 3</mark> 次のデータは、**例題3**と同じ年のB市における月毎の降水日数である。
# ```python
# rain_B = [19, 16, 12, 11, 6, 8, 21, 13, 10, 14, 18, 22]
# ```
# このデータの「範囲」を求め、データの散らばりの度合いが大きいのはA市、B市のどちらと考えられるか。

# %% [markdown]
# 解答：

# %% [markdown]
# <mark>演習 4</mark> 次のデータの分散、標準偏差を2つの計算方法
# $$\sigma^2 = \frac{1}{n}\sum_{i=1}^n (x_i - \bar{x})^2$$
# $$\sigma^2 = \overline{x^2}-(\bar{x})^2$$
# でそれぞれ求め、両者が一致することを確かめなさい。
# ```python
# x = [6, 10, 7, 7, 5, 4, 9, 10, 5, 7]
# ```
