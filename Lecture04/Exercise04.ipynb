# %% [markdown]
# <mark>演習 1</mark> 日本の各都市の標高と年平均気温についてデータ`elev-temp.csv`を散布図としてプロットしなさい。このデータにはどのような相関があると言えるでしょうか?

# %% [markdown]
# <mark>演習 2</mark> `height-weight.csv`、`elev-temp.csv`の
# それぞれのデータに対して共分散を求めるプログラムを作成しなさい。

# %% [markdown]
# <mark>演習 3</mark> 講義内で定義した関数`r(x,y)`を使って、`tokyo-temp.csv`、`height-weight.csv`、`elev-temp.csv`のそれぞれのデータの相関係数を求めるプログラムを作成しなさい。

# %% [markdown]
# <mark>発展問題</mark> 共分散や相関係数を求めるには、与えたデータの$x_i$と$y_i$の個数が一致する必要がある。（必ず、$(x_i,y_i)$というデータのペアとなる。）授業で定義した関数`cov(x,y)`や`r(x,y)`ではデータの個数が一致することを前提としているが、個数が異なる場合にはエラーを返す(あるいはエラー処理を行う)ような関数に改良しなさい。
