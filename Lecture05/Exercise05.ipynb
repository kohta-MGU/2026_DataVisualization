# %% [markdown]
# <mark>演習 1</mark> $y=\sin x$のグラフと$y=\cos x$のグラフを$0\leq x \leq 4\pi$の範囲で重ねて描きなさい。

# %% [markdown]
# <mark>演習 2</mark> サイコロを2つ同時に振った時、それぞれの目の合計の値が出る割合を乱数を使って計算してみましょう。また、確率計算からの予測と実験の結果を比較してみましょう。

# %% [markdown]
# <mark>演習 3</mark> 練習 7を参考に、横軸をステップ数`N`、縦軸を標準偏差$\sigma$として、`N`を1から100まで変化させたときのグラフをプロットしなさい。(サンプル数は1000に固定する。)
#
# ⚠️ `N`は1から100までの整数値になる。

# %% [markdown]
# <mark>演習 4</mark> 演習3で作成したグラフに
# $$\sigma = \frac{\sqrt{N}}{2}$$
# のグラフを重ねてプロットしなさい。

# %% [markdown]
# <mark>発展問題</mark> 疑似乱数を発生させるアルゴリズムについて調べ、Pythonで自作関数として実装しなさい。
